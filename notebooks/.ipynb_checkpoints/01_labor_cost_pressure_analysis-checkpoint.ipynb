# %% [markdown]
#  # Exploratory Data Analysis (EDA)
#
# ## Project
# Private Equity Acquisitions and Worker Outcomes (Industry-Level)
#
# ## Purpose
# This notebook performs initial descriptive analysis of industry-level labor outcomes
# and private equity exposure. The goal is to understand data coverage, trends, and
# basic relationships prior to any modeling.
#
# No causal claims are made in this notebook.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from pathlib import Path

raw_dirs = [
    Path("/Users/brockjohnson/Downloads/2024.annual.by_area"),
    Path("/Users/brockjohnson/Downloads/2023.annual.by_area"),
    Path("/Users/brockjohnson/Downloads/2022.annual.by_area"),
    Path("/Users/brockjohnson/Downloads/2021.annual.by_area"),
    Path("/Users/brockjohnson/Downloads/2020.annual.by_area"),
]

# %%
files = []
for d in raw_dirs:
    files.extend(d.glob("*.csv"))

len(files)
# Out:
# 15355

# %%
import pandas as pd

dfs = []
for f in files:
    df = pd.read_csv(f, dtype=str)
    dfs.append(df)

qcew = pd.concat(dfs, ignore_index=True)
qcew.shape
# Out:
# (11116483, 43)

# %%
qcew_us = qcew[
    (qcew["area_fips"] == "US000") &  # U.S. TOTAL
    (qcew["own_code"] == "0") &      # Total Covered
    (qcew["qtr"] == "A")             # Annual
].copy()

qcew_us.shape
# Out:
# (3, 43)

# %%
qcew_us[["agglvl_code", "agglvl_title"]].drop_duplicates().sort_values("agglvl_code")
# Out:
#        agglvl_code             agglvl_title
# 295995          10  National, Total Covered

# %%
qcew_us[["industry_code", "industry_title"]].drop_duplicates().head(30)
# Out:
#        industry_code            industry_title
# 295995            10  10 Total, all industries

# %%
qcew_us["industry_code"].value_counts().head(20)
# Out:
# industry_code
# 10    3
# Name: count, dtype: int64

# %%
from pathlib import Path

industry_dirs = [
    Path("/Users/brockjohnson/Downloads/2024.annual.by_industry"),
    Path("/Users/brockjohnson/Downloads/2023.annual.by_industry"),
    Path("/Users/brockjohnson/Downloads/2022.annual.by_industry"),
    Path("/Users/brockjohnson/Downloads/2021.annual.by_industry"),
    Path("/Users/brockjohnson/Downloads/2020.annual.by_industry"),
]

# %%
files = []
for d in industry_dirs:
    files.extend(d.glob("*.csv"))

len(files)
# Out:
# 10939

# %%
import pandas as pd

dfs = []
for f in files:
    df = pd.read_csv(f, dtype=str)
    dfs.append(df)

qcew_ind = pd.concat(dfs, ignore_index=True)
qcew_ind.shape
# Out:
# (18169564, 43)

# %%
qcew_ind[["industry_code", "industry_title"]].drop_duplicates().head(20)
# Out:
#       industry_code                                     industry_title
# 0            444120         NAICS 444120 Paint and wallpaper retailers
# 1899          92214              NAICS 92214 Correctional institutions
# 4072         512191  NAICS 512191 Teleproduction and other postprod...
# 4848         325194  NAICS 325194 Cyclic crude, intermediate, and g...
# 5002         333248  NAICS 333248 All other industrial machinery ma...
# 6262         423320  NAICS 423320 Brick, stone, and related constru...
# 7948          48521  NAICS 48521 Interurban and rural bus transport...
# 8559          45931                               NAICS 45931 Florists
# 11392           111                          NAICS 111 Crop production
# 14775         81221     NAICS 81221 Funeral homes and funeral services
# 18009        325414  NAICS 325414 Biological product (except diagno...
# 18541        323113            NAICS 323113 Commercial screen printing
# 20589         53311  NAICS 53311 Lessors of nonfinancial intangible...
# 21634         56199             NAICS 56199 All other support services
# 24237          3271  NAICS 3271 Clay product and refractory manufac...
# 25203         62131               NAICS 62131 Offices of chiropractors
# 28165            53        NAICS 53 Real estate and rental and leasing
# 32839         11211  NAICS 11211 Beef cattle ranching and farming, ...
# 35389         42394  NAICS 42394 Jewelry, watch, precious stone, an...
# 36484         44122  NAICS 44122 Motorcycle, boat, and other motor ...

# %%
qcew_ind[["agglvl_code", "agglvl_title"]].drop_duplicates().sort_values("agglvl_code")
# Out:
#         agglvl_code                                     agglvl_title
# 2728168          10                          National, Total Covered
# 2728169          11           National, Total -- by ownership sector
# 2678466          12       National, by Domain -- by ownership sector
# 148382           13  National, by Supersector -- by ownership sector
# 32835            14    National, NAICS Sector -- by ownership sector
# 14771            15   National, NAICS 3-digit -- by ownership sector
# 25202            16   National, NAICS 4-digit -- by ownership sector
# 4069             17   National, NAICS 5-digit -- by ownership sector
# 1898             18   National, NAICS 6-digit -- by ownership sector
# 2727984          30                       CMSA or CSA, Total Covered
# 2725480          40                               MSA, Total Covered
# 2725481          41                MSA, Total -- by ownership sector
# 2678073          42            MSA, by Domain -- by ownership sector
# 270250           43       MSA, by Supersector -- by ownership sector
# 32442            44         MSA, NAICS Sector -- by ownership sector
# 14380            45        MSA, NAICS 3-digit -- by ownership sector
# 24959            46        MSA, NAICS 4-digit -- by ownership sector
# 8414             47        MSA, NAICS 5-digit -- by ownership sector
# 1509             48        MSA, NAICS 6-digit -- by ownership sector
# 2708879          50                             State, Total Covered
# 2708880          51              State, Total -- by ownership sector
# 2664866          52          State, by Domain -- by ownership sector
# 138754           53     State, by Supersector -- by ownership sector
# 28165            54       State, NAICS Sector -- by ownership sector
# 11392            55      State, NAICS 3-digit -- by ownership sector
# 24237            56      State, NAICS 4-digit -- by ownership sector
# 1899             57      State, NAICS 5-digit -- by ownership sector
# 0                58      State, NAICS 6-digit -- by ownership sector
# 2708885          70                            County, Total Covered
# 2708886          71             County, Total -- by ownership sector
# 2664870          72         County, by Domain -- by ownership sector
# 138757           73    County, by Supersector -- by ownership sector
# 28167            74      County, NAICS Sector -- by ownership sector
# 11393            75     County, NAICS 3-digit -- by ownership sector
# 24238            76     County, NAICS 4-digit -- by ownership sector
# 1902             77     County, NAICS 5-digit -- by ownership sector
# 1                78     County, NAICS 6-digit -- by ownership sector
# 2725478          80                           MicroSA, Total Covered
# 2728176          91                             Total, all U.S. MSAs
# 2728175          92           Total, all U.S. CMSAs or all U.S. CSAs
# 2728177          93                 Total, all U.S. non-MSA counties
# 2728174          94                        Total U.I. Covered (U.S.)
# 2728173          95                          Total Government (U.S.)
# 2708884          96                       Total Government, by State

# %%
qcew_sector = (
    qcew_ind
    .loc[
        (qcew_ind["agglvl_code"] == "14") &  # National, NAICS Sector
        (qcew_ind["own_code"] == "1") &      # Private sector
        (qcew_ind["qtr"] == "A")             # Annual
    ]
    .copy()
)

qcew_sector.shape
# Out:
# (91, 43)

# %%
qcew_ind.loc[qcew_ind["agglvl_code"] == "14", "own_code"].value_counts()
# Out:
# own_code
# 3    100
# 5    100
# 2     92
# 1     91
# Name: count, dtype: int64

# %%
qcew_sector = qcew_ind[
    (qcew_ind["agglvl_code"] == "14") &
    (qcew_ind["own_code"] == "1") &   # Private sector
    (qcew_ind["qtr"] == "A")
].copy()

qcew_sector.shape
# Out:
# (91, 43)

# %%
qcew_sector["own_code"].value_counts()
# Out:
# own_code
# 1    91
# Name: count, dtype: int64

# %%
qcew_sector[["industry_code", "industry_title"]].drop_duplicates().sort_values("industry_code")
# Out:
#          industry_code                                     industry_title
# 3447851             11  NAICS 11 Agriculture, forestry, fishing and hu...
# 1558507             22                                 NAICS 22 Utilities
# 1482115             23                              NAICS 23 Construction
# 3437384          31-33                          NAICS 31-33 Manufacturing
# 3000118             42                           NAICS 42 Wholesale trade
# 1685980          44-45                           NAICS 44-45 Retail trade
# 2242382          48-49         NAICS 48-49 Transportation and warehousing
# 2870112             51                               NAICS 51 Information
# 193062              52                     NAICS 52 Finance and insurance
# 32835               53        NAICS 53 Real estate and rental and leasing
# 3642535             54  NAICS 54 Professional, scientific, and technic...
# 11015932            54       NAICS 54 Professional and technical services
# 3585741             56  NAICS 56 Administrative and support and waste ...
# 14397091            56         NAICS 56 Administrative and waste services
# 236856              61                      NAICS 61 Educational services
# 3415733             62         NAICS 62 Health care and social assistance
# 3367638             71       NAICS 71 Arts, entertainment, and recreation
# 3307565             72           NAICS 72 Accommodation and food services
# 11222370            81  NAICS 81 Other services, except public adminis...
# 1752276             81  NAICS 81 Other services (except public adminis...
# 512806              92                     NAICS 92 Public administration
# 2042841             99                              NAICS 99 Unclassified

# %%
qcew_sector["own_code"].value_counts()
# Out:
# own_code
# 1    91
# Name: count, dtype: int64

# %%
qcew_sector[["industry_code", "industry_title"]].drop_duplicates().sort_values("industry_code")
# Out:
#          industry_code                                     industry_title
# 3447851             11  NAICS 11 Agriculture, forestry, fishing and hu...
# 1558507             22                                 NAICS 22 Utilities
# 1482115             23                              NAICS 23 Construction
# 3437384          31-33                          NAICS 31-33 Manufacturing
# 3000118             42                           NAICS 42 Wholesale trade
# 1685980          44-45                           NAICS 44-45 Retail trade
# 2242382          48-49         NAICS 48-49 Transportation and warehousing
# 2870112             51                               NAICS 51 Information
# 193062              52                     NAICS 52 Finance and insurance
# 32835               53        NAICS 53 Real estate and rental and leasing
# 3642535             54  NAICS 54 Professional, scientific, and technic...
# 11015932            54       NAICS 54 Professional and technical services
# 3585741             56  NAICS 56 Administrative and support and waste ...
# 14397091            56         NAICS 56 Administrative and waste services
# 236856              61                      NAICS 61 Educational services
# 3415733             62         NAICS 62 Health care and social assistance
# 3367638             71       NAICS 71 Arts, entertainment, and recreation
# 3307565             72           NAICS 72 Accommodation and food services
# 11222370            81  NAICS 81 Other services, except public adminis...
# 1752276             81  NAICS 81 Other services (except public adminis...
# 512806              92                     NAICS 92 Public administration
# 2042841             99                              NAICS 99 Unclassified

# %%
#Convert key columns to numeric
num_cols = [
    "annual_avg_emplvl",
    "total_annual_wages",
    "annual_avg_wkly_wage"
]

for c in num_cols:
    qcew_sector[c] = pd.to_numeric(qcew_sector[c], errors="coerce")

# %%
# quick check
qcew_sector[num_cols].describe()
# Out:
#        annual_avg_emplvl  total_annual_wages  annual_avg_wkly_wage
# count       9.100000e+01        9.100000e+01             91.000000
# mean        1.605074e+05        1.500901e+10           1619.868132
# std         3.896441e+05        3.944938e+10            735.904375
# min         0.000000e+00        0.000000e+00              0.000000
# 25%         3.682500e+03        2.407447e+08           1124.500000
# 50%         1.192100e+04        1.181490e+09           1677.000000
# 75%         4.909800e+04        4.493715e+09           1987.000000
# max         1.675418e+06        1.904169e+11           3184.000000

# %%
#Create Industry x Year df
panel = (
    qcew_sector
    .sort_values(["industry_code", "year"])
    .reset_index(drop=True)
)

panel.head()
# Out:
#   area_fips own_code industry_code agglvl_code size_code  year qtr  \
# 0     US000        1            11          14         0  2020   A
# 1     US000        1            11          14         0  2021   A
# 2     US000        1            11          14         0  2022   A
# 3     US000        1            11          14         0  2023   A
# 4     US000        1            11          14         0  2024   A
#
#   disclosure_code  area_title           own_title  ...  \
# 0             NaN  U.S. TOTAL  Federal Government  ...
# 1             NaN  U.S. TOTAL  Federal Government  ...
# 2             NaN  U.S. TOTAL  Federal Government  ...
# 3             NaN  U.S. TOTAL  Federal Government  ...
# 4             NaN  U.S. TOTAL  Federal Government  ...
#
#   oty_total_annual_wages_chg oty_total_annual_wages_pct_chg  \
# 0                   22254175                            8.7
# 1                   15159691                            5.5
# 2                   15452526                            5.3
# 3                   23766842                            7.7
# 4                   46956683                           14.1
#
#   oty_taxable_annual_wages_chg oty_taxable_annual_wages_pct_chg  \
# 0                            0                              0.0
# 1                            0                              0.0
# 2                            0                              0.0
# 3                            0                              0.0
# 4                            0                              0.0
#
#    oty_annual_contributions_chg  oty_annual_contributions_pct_chg  \
# 0                             0                               0.0
# 1                             0                               0.0
# 2                             0                               0.0
# 3                             0                               0.0
# 4                             0                               0.0
#
#   oty_annual_avg_wkly_wage_chg oty_annual_avg_wkly_wage_pct_chg  \
# 0                          124                              9.3
# 1                           67                              4.6
# 2                           92                              6.0
# 3                           86                              5.3
# 4                          131                              7.7
#
#    oty_avg_annual_pay_chg oty_avg_annual_pay_pct_chg
# 0                    6487                        9.3
# 1                    3449                        4.5
# 2                    4813                        6.1
# 3                    4479                        5.3
# 4                    6791                        7.7
#
# [5 rows x 43 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

for ind, df in panel.groupby("industry_title"):
    plt.plot(df["year"], df["annual_avg_emplvl"], alpha=0.7)

plt.title("U.S. Private-Sector Employment by NAICS Sector (Annual)")
plt.xlabel("Year")
plt.ylabel("Average Employment Level")
plt.tight_layout()
plt.show()

# %%
panel_indexed = panel.copy()

panel_indexed["empl_index_2020"] = (
    panel_indexed
    .groupby("industry_code")["annual_avg_emplvl"]
    .transform(lambda x: 100 * x / x.iloc[0])
)

# %%
plt.figure(figsize=(10, 6))

for ind, df in panel_indexed.groupby("industry_title"):
    plt.plot(df["year"], df["empl_index_2020"], alpha=0.7)

plt.axhline(100, linestyle="--", linewidth=1)
plt.title("U.S. Private-Sector Employment by NAICS Sector (Indexed to 2020 = 100)")
plt.xlabel("Year")
plt.ylabel("Employment Index (2020 = 100)")
plt.yscale("log")
plt.tight_layout()
plt.show()

# %%
# How many distinct years do we have per industry?
(panel.groupby("industry_title")["year"]
 .nunique()
 .sort_values()
 .head(20))
# Out:
# industry_title
# NAICS 42 Wholesale trade                                                             1
# NAICS 54 Professional and technical services                                         2
# NAICS 81 Other services, except public administration                                2
# NAICS 56 Administrative and waste services                                           2
# NAICS 81 Other services (except public administration)                               3
# NAICS 56 Administrative and support and waste management and remediation services    3
# NAICS 54 Professional, scientific, and technical services                            3
# NAICS 72 Accommodation and food services                                             5
# NAICS 71 Arts, entertainment, and recreation                                         5
# NAICS 62 Health care and social assistance                                           5
# NAICS 61 Educational services                                                        5
# NAICS 11 Agriculture, forestry, fishing and hunting                                  5
# NAICS 53 Real estate and rental and leasing                                          5
# NAICS 52 Finance and insurance                                                       5
# NAICS 51 Information                                                                 5
# NAICS 48-49 Transportation and warehousing                                           5
# NAICS 44-45 Retail trade                                                             5
# NAICS 31-33 Manufacturing                                                            5
# NAICS 23 Construction                                                                5
# NAICS 22 Utilities                                                                   5
# Name: year, dtype: int64

# %%
# Create a canonical title per industry_code (most common title)
industry_labels = (
    panel
    .groupby("industry_code")["industry_title"]
    .agg(lambda x: x.value_counts().index[0])
)

industry_labels
# Out:
# industry_code
# 11       NAICS 11 Agriculture, forestry, fishing and hu...
# 22                                      NAICS 22 Utilities
# 23                                   NAICS 23 Construction
# 31-33                            NAICS 31-33 Manufacturing
# 42                                NAICS 42 Wholesale trade
# 44-45                             NAICS 44-45 Retail trade
# 48-49           NAICS 48-49 Transportation and warehousing
# 51                                    NAICS 51 Information
# 52                          NAICS 52 Finance and insurance
# 53             NAICS 53 Real estate and rental and leasing
# 54       NAICS 54 Professional, scientific, and technic...
# 56       NAICS 56 Administrative and support and waste ...
# 61                           NAICS 61 Educational services
# 62              NAICS 62 Health care and social assistance
# 71            NAICS 71 Arts, entertainment, and recreation
# 72                NAICS 72 Accommodation and food services
# 81       NAICS 81 Other services (except public adminis...
# 92                          NAICS 92 Public administration
# 99                                   NAICS 99 Unclassified
# Name: industry_title, dtype: object

# %%
panel_clean = panel.copy()
panel_clean["industry_title_clean"] = panel_clean["industry_code"].map(industry_labels)

# %%
(panel_clean.groupby("industry_code")["year"]
 .nunique()
 .sort_values())
# Out:
# industry_code
# 42       1
# 11       5
# 81       5
# 72       5
# 71       5
# 62       5
# 61       5
# 56       5
# 54       5
# 53       5
# 52       5
# 51       5
# 48-49    5
# 44-45    5
# 31-33    5
# 23       5
# 22       5
# 92       5
# 99       5
# Name: year, dtype: int64

# %%
complete_inds = (
    panel_clean
    .groupby("industry_code")["year"]
    .nunique()
    .loc[lambda x: x == 5]
    .index
)

# %%
complete_inds
# Out:
# Index(['11', '22', '23', '31-33', '44-45', '48-49', '51', '52', '53', '54',
#        '56', '61', '62', '71', '72', '81', '92', '99'],
#       dtype='object', name='industry_code')

# %%
naics_sectors = [
    '11', '22', '23', '31-33', '44-45', '48-49',
    '51', '52', '53', '54', '56', '61', '62',
    '71', '72', '81'
]

# %%
panel_final = panel_clean[
    panel_clean["industry_code"].isin(naics_sectors)
].copy()

# %%
(panel_final.groupby("industry_code")["year"]
 .nunique()
 .value_counts())
# Out:
# year
# 5    16
# Name: count, dtype: int64

# %% [markdown]
# ## Core Data Construction (Run Before Analysis)

# %%
# Ensure numeric types
panel_final["year"] = pd.to_numeric(panel_final["year"], errors="coerce")
panel_final["annual_avg_emplvl"] = pd.to_numeric(panel_final["annual_avg_emplvl"], errors="coerce")
panel_final["annual_avg_wkly_wage"] = pd.to_numeric(panel_final["annual_avg_wkly_wage"], errors="coerce")

# Employment (headcount)
wide = panel_final.pivot_table(
    index=["industry_code", "industry_title_clean"],
    columns="year",
    values="annual_avg_emplvl",
    aggfunc="sum"
)

# Wages (per worker)
wide_wage = panel_final.pivot_table(
    index=["industry_code", "industry_title_clean"],
    columns="year",
    values="annual_avg_wkly_wage",
    aggfunc="mean"
)

# Payroll proxy (total labor spend)
panel_final["payroll_approx"] = (
    panel_final["annual_avg_wkly_wage"] *
    panel_final["annual_avg_emplvl"] * 52
)

wide_payroll = panel_final.pivot_table(
    index=["industry_code", "industry_title_clean"],
    columns="year",
    values="payroll_approx",
    aggfunc="sum"
)

# %%
wide.columns, wide.columns.dtype
# Out:
# (Index([2020, 2021, 2022, 2023, 2024], dtype='int64', name='year'),
#  dtype('int64'))

# %%
wide = panel_final.pivot_table(
    index=["industry_code", "industry_title_clean"],
    columns="year",
    values="annual_avg_emplvl",
    aggfunc="sum"
)

wide
# Out:
# year                                                                2020  \
# industry_code industry_title_clean
# 11            NAICS 11 Agriculture, forestry, fishing and hun...    3665
# 22            NAICS 22 Utilities                                   11408
# 23            NAICS 23 Construction                                    4
# 31-33         NAICS 31-33 Manufacturing                            50949
# 44-45         NAICS 44-45 Retail trade                             43653
# 48-49         NAICS 48-49 Transportation and warehousing          615321
# 51            NAICS 51 Information                                  6640
# 52            NAICS 52 Finance and insurance                       12066
# 53            NAICS 53 Real estate and rental and leasing             29
# 54            NAICS 54 Professional, scientific, and technica...   67249
# 56            NAICS 56 Administrative and support and waste m...    1795
# 61            NAICS 61 Educational services                        12536
# 62            NAICS 62 Health care and social assistance          412779
# 71            NAICS 71 Arts, entertainment, and recreation         36722
# 72            NAICS 72 Accommodation and food services              8674
# 81            NAICS 81 Other services (except public administ...    4492
#
# year                                                                2021  \
# industry_code industry_title_clean
# 11            NAICS 11 Agriculture, forestry, fishing and hun...    3696
# 22            NAICS 22 Utilities                                   11552
# 23            NAICS 23 Construction                                    5
# 31-33         NAICS 31-33 Manufacturing                            50240
# 44-45         NAICS 44-45 Retail trade                             42057
# 48-49         NAICS 48-49 Transportation and warehousing          618972
# 51            NAICS 51 Information                                  6551
# 52            NAICS 52 Finance and insurance                       12348
# 53            NAICS 53 Real estate and rental and leasing             29
# 54            NAICS 54 Professional, scientific, and technica...   67801
# 56            NAICS 56 Administrative and support and waste m...    1680
# 61            NAICS 61 Educational services                        12594
# 62            NAICS 62 Health care and social assistance          416646
# 71            NAICS 71 Arts, entertainment, and recreation         37031
# 72            NAICS 72 Accommodation and food services              7753
# 81            NAICS 81 Other services (except public administ...    4772
#
# year                                                                2022  \
# industry_code industry_title_clean
# 11            NAICS 11 Agriculture, forestry, fishing and hun...    3669
# 22            NAICS 22 Utilities                                   11496
# 23            NAICS 23 Construction                                    5
# 31-33         NAICS 31-33 Manufacturing                            48792
# 44-45         NAICS 44-45 Retail trade                             41000
# 48-49         NAICS 48-49 Transportation and warehousing          615190
# 51            NAICS 51 Information                                  6493
# 52            NAICS 52 Finance and insurance                       12463
# 53            NAICS 53 Real estate and rental and leasing             20
# 54            NAICS 54 Professional, scientific, and technica...   67376
# 56            NAICS 56 Administrative and support and waste m...    1603
# 61            NAICS 61 Educational services                        12312
# 62            NAICS 62 Health care and social assistance          414363
# 71            NAICS 71 Arts, entertainment, and recreation         37427
# 72            NAICS 72 Accommodation and food services              7294
# 81            NAICS 81 Other services (except public administ...    4819
#
# year                                                                2023  \
# industry_code industry_title_clean
# 11            NAICS 11 Agriculture, forestry, fishing and hun...    3751
# 22            NAICS 22 Utilities                                   11921
# 23            NAICS 23 Construction                                    5
# 31-33         NAICS 31-33 Manufacturing                            48401
# 44-45         NAICS 44-45 Retail trade                             40355
# 48-49         NAICS 48-49 Transportation and warehousing          618284
# 51            NAICS 51 Information                                  6575
# 52            NAICS 52 Finance and insurance                       12664
# 53            NAICS 53 Real estate and rental and leasing             23
# 54            NAICS 54 Professional, scientific, and technica...   68999
# 56            NAICS 56 Administrative and support and waste m...    1686
# 61            NAICS 61 Educational services                        12528
# 62            NAICS 62 Health care and social assistance          430150
# 71            NAICS 71 Arts, entertainment, and recreation         39600
# 72            NAICS 72 Accommodation and food services              7865
# 81            NAICS 81 Other services (except public administ...    4909
#
# year                                                                2024
# industry_code industry_title_clean
# 11            NAICS 11 Agriculture, forestry, fishing and hun...    3976
# 22            NAICS 22 Utilities                                    9744
# 23            NAICS 23 Construction                                   27
# 31-33         NAICS 31-33 Manufacturing                            49404
# 44-45         NAICS 44-45 Retail trade                             39904
# 48-49         NAICS 48-49 Transportation and warehousing          619830
# 51            NAICS 51 Information                                  6674
# 52            NAICS 52 Finance and insurance                       13143
# 53            NAICS 53 Real estate and rental and leasing             26
# 54            NAICS 54 Professional, scientific, and technica...   71065
# 56            NAICS 56 Administrative and support and waste m...    1700
# 61            NAICS 61 Educational services                        12771
# 62            NAICS 62 Health care and social assistance          443782
# 71            NAICS 71 Arts, entertainment, and recreation         40467
# 72            NAICS 72 Accommodation and food services              8271
# 81            NAICS 81 Other services (except public administ...    5002

# %%
growth = (
    (wide[2024] / wide[2020] - 1)
    .rename("empl_growth_2020_2024")
    .reset_index()
    .sort_values("empl_growth_2020_2024", ascending=False)
)

growth
# Out:
#    industry_code                               industry_title_clean  \
# 2             23                              NAICS 23 Construction
# 15            81  NAICS 81 Other services (except public adminis...
# 13            71       NAICS 71 Arts, entertainment, and recreation
# 7             52                     NAICS 52 Finance and insurance
# 0             11  NAICS 11 Agriculture, forestry, fishing and hu...
# 12            62         NAICS 62 Health care and social assistance
# 9             54  NAICS 54 Professional, scientific, and technic...
# 11            61                      NAICS 61 Educational services
# 5          48-49         NAICS 48-49 Transportation and warehousing
# 6             51                               NAICS 51 Information
# 3          31-33                          NAICS 31-33 Manufacturing
# 14            72           NAICS 72 Accommodation and food services
# 10            56  NAICS 56 Administrative and support and waste ...
# 4          44-45                           NAICS 44-45 Retail trade
# 8             53        NAICS 53 Real estate and rental and leasing
# 1             22                                 NAICS 22 Utilities
#
#     empl_growth_2020_2024
# 2                5.750000
# 15               0.113535
# 13               0.101982
# 7                0.089259
# 0                0.084857
# 12               0.075108
# 9                0.056744
# 11               0.018746
# 5                0.007328
# 6                0.005120
# 3               -0.030324
# 14              -0.046461
# 10              -0.052925
# 4               -0.085882
# 8               -0.103448
# 1               -0.145863

# %%
growth_rounded = growth.copy()
growth_rounded["empl_growth_pct"] = (
    100 * growth_rounded["empl_growth_2020_2024"]
).round(2)

growth_rounded
# Out:
#    industry_code                               industry_title_clean  \
# 2             23                              NAICS 23 Construction
# 15            81  NAICS 81 Other services (except public adminis...
# 13            71       NAICS 71 Arts, entertainment, and recreation
# 7             52                     NAICS 52 Finance and insurance
# 0             11  NAICS 11 Agriculture, forestry, fishing and hu...
# 12            62         NAICS 62 Health care and social assistance
# 9             54  NAICS 54 Professional, scientific, and technic...
# 11            61                      NAICS 61 Educational services
# 5          48-49         NAICS 48-49 Transportation and warehousing
# 6             51                               NAICS 51 Information
# 3          31-33                          NAICS 31-33 Manufacturing
# 14            72           NAICS 72 Accommodation and food services
# 10            56  NAICS 56 Administrative and support and waste ...
# 4          44-45                           NAICS 44-45 Retail trade
# 8             53        NAICS 53 Real estate and rental and leasing
# 1             22                                 NAICS 22 Utilities
#
#     empl_growth_2020_2024  empl_growth_pct
# 2                5.750000           575.00
# 15               0.113535            11.35
# 13               0.101982            10.20
# 7                0.089259             8.93
# 0                0.084857             8.49
# 12               0.075108             7.51
# 9                0.056744             5.67
# 11               0.018746             1.87
# 5                0.007328             0.73
# 6                0.005120             0.51
# 3               -0.030324            -3.03
# 14              -0.046461            -4.65
# 10              -0.052925            -5.29
# 4               -0.085882            -8.59
# 8               -0.103448           -10.34
# 1               -0.145863           -14.59

# %% [markdown]
# ### Observation
# Construction shows extreme post-2020 growth due to a depressed 2020 base.
# This is treated as a base-year artifact and excluded from visualizations,
# but retained in the underlying table.

# %%
# Removing outlier industry code 23
growth_plot = growth_rounded[
    growth_rounded["industry_code"] != "23"
]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.barh(
    growth_plot["industry_title_clean"],
    growth_plot["empl_growth_pct"]
)
plt.axvline(0, linestyle="--", linewidth=1)
plt.title("Cumulative Employment Growth by Industry (2020–2024)\n(Excluding Construction)")
plt.xlabel("Employment Growth (%)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Employment vs Wage Dynamics
#
# After examining employment growth by industry, the next step is to compare
# employment changes with wage changes. Divergence between these measures
# (e.g., wages rising while employment stagnates or declines) can signal
# labor market tightness, productivity changes, or restructuring pressures.

# %%
# Ensure wage measure is numeric
panel_final["annual_avg_wkly_wage"] = pd.to_numeric(
    panel_final["annual_avg_wkly_wage"], errors="coerce"
)

# Pivot wages to wide format (industry × year)
wide_wage = panel_final.pivot_table(
    index=["industry_code", "industry_title_clean"],
    columns="year",
    values="annual_avg_wkly_wage",
    aggfunc="mean"  # wages should be averaged, not summed
)

# Compute cumulative wage growth from 2020 to 2024
wage_growth = (
    (wide_wage[2024] / wide_wage[2020] - 1)
    .rename("wage_growth_2020_2024")
    .reset_index()
)

# %%
# Merge employment and wage growth into a single table
growth_combined = growth.merge(
    wage_growth,
    on=["industry_code", "industry_title_clean"],
    how="inner"
)

# Convert to percentages and round for readability
growth_combined["empl_growth_pct"] = (
    100 * growth_combined["empl_growth_2020_2024"]
).round(2)

growth_combined["wage_growth_pct"] = (
    100 * growth_combined["wage_growth_2020_2024"]
).round(2)

growth_combined[
    ["industry_title_clean", "empl_growth_pct", "wage_growth_pct"]
].sort_values("wage_growth_pct", ascending=False)
# Out:
#                                  industry_title_clean  empl_growth_pct  \
# 11           NAICS 72 Accommodation and food services            -4.65
# 4   NAICS 11 Agriculture, forestry, fishing and hu...             8.49
# 12  NAICS 56 Administrative and support and waste ...            -5.29
# 5          NAICS 62 Health care and social assistance             7.51
# 3                      NAICS 52 Finance and insurance             8.93
# 1   NAICS 81 Other services (except public adminis...            11.35
# 14        NAICS 53 Real estate and rental and leasing           -10.34
# 2        NAICS 71 Arts, entertainment, and recreation            10.20
# 9                                NAICS 51 Information             0.51
# 10                          NAICS 31-33 Manufacturing            -3.03
# 13                           NAICS 44-45 Retail trade            -8.59
# 15                                 NAICS 22 Utilities           -14.59
# 7                       NAICS 61 Educational services             1.87
# 0                               NAICS 23 Construction           575.00
# 8          NAICS 48-49 Transportation and warehousing             0.73
# 6   NAICS 54 Professional, scientific, and technic...             5.67
#
#     wage_growth_pct
# 11            40.96
# 4             25.77
# 12            24.33
# 5             22.65
# 3             20.60
# 1             19.64
# 14            18.29
# 2             17.91
# 9             17.63
# 10            16.99
# 13            15.98
# 15            15.59
# 7             13.17
# 0             11.80
# 8             10.19
# 6             10.09

# %% [markdown]
# ### Initial observations
#
# Comparing employment and wage growth reveals several industries where
# wages increased despite flat or declining employment. These patterns
# may reflect labor shortages, productivity changes, or cost pressures
# that differ by industry.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 6))

plt.scatter(
    growth_combined["empl_growth_pct"],
    growth_combined["wage_growth_pct"]
)

# Label each point with the industry name
for _, row in growth_combined.iterrows():
    plt.text(
        row["empl_growth_pct"],
        row["wage_growth_pct"],
        row["industry_title_clean"].replace("NAICS ", ""),
        fontsize=8,
        alpha=0.8
    )

# Reference lines
plt.axhline(0, linestyle="--", linewidth=1)
plt.axvline(0, linestyle="--", linewidth=1)

plt.xlabel("Employment Growth (2020–2024, %)")
plt.ylabel("Wage Growth (2020–2024, %)")
plt.title("Employment vs Wage Growth by Industry")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Visualization choice
#
# Construction exhibits extreme employment growth due to a depressed 2020 base.
# To improve interpretability, Construction is excluded from the main scatter
# plot but retained in the underlying data and discussed separately.

# %%
# Exclude Construction (NAICS 23) for visualization clarity
scatter_data = growth_combined[
    growth_combined["industry_code"] != "23"
].copy()

# %%
key_inds = [
    "Accommodation and food services",
    "Administrative and support and waste management and remediation services",
    "Health care and social assistance",
    "Retail trade",
    "Utilities"
]

plt.figure(figsize=(7, 6))
plt.scatter(
    scatter_data["empl_growth_pct"],
    scatter_data["wage_growth_pct"]
)

for _, row in scatter_data.iterrows():
    label = row["industry_title_clean"].replace("NAICS ", "")
    if label in key_inds:
        plt.text(
            row["empl_growth_pct"] + 0.3,
            row["wage_growth_pct"] + 0.3,
            label,
            fontsize=9,
            fontweight="bold"
        )

plt.axhline(0, linestyle="--", linewidth=1)
plt.axvline(0, linestyle="--", linewidth=1)
plt.xlim(-20, 20)

plt.xlabel("Employment Growth (2020–2024, %)")
plt.ylabel("Wage Growth (2020–2024, %)")
plt.title("Employment vs Wage Growth by Industry\n(Key Industries Highlighted)")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Use the no-outlier version for readability (keep Construction separate)
scatter_data = growth_combined[growth_combined["industry_code"] != "23"].copy()

# Build a stable list of industries and assign each one a color index
industries = sorted(scatter_data["industry_title_clean"].unique())
color_map = {ind: i for i, ind in enumerate(industries)}

# Choose a categorical colormap with many distinct colors
cmap = plt.get_cmap("tab20", len(industries))

plt.figure(figsize=(7, 6))

# Plot each industry as its own series so it appears in the legend
for ind in industries:
    df = scatter_data[scatter_data["industry_title_clean"] == ind]
    plt.scatter(
        df["empl_growth_pct"],
        df["wage_growth_pct"],
        label=ind.replace("NAICS ", ""),
        color=cmap(color_map[ind])
    )

# Reference lines
plt.axhline(0, linestyle="--", linewidth=1)
plt.axvline(0, linestyle="--", linewidth=1)

# Tighten x-axis to focus on the clustered industries
plt.xlim(-20, 20)

plt.xlabel("Employment Growth (2020–2024, %)")
plt.ylabel("Wage Growth (2020–2024, %)")
plt.title("Employment vs Wage Growth by Industry\n(Colored Key in Legend)")

# Put the legend outside so it doesn’t cover points
plt.legend(
    bbox_to_anchor=(1.02, 1),
    loc="upper left",
    borderaxespad=0,
    ncol=1,
    fontsize=8
)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Use the cleaned scatter data (Construction already excluded)
scatter_data = growth_combined[growth_combined["industry_code"] != "23"].copy()

# Build a stable list of industries
industries = sorted(scatter_data["industry_title_clean"].unique())

# Assign each industry a color index
color_map = {ind: i for i, ind in enumerate(industries)}

# Categorical colormap with enough distinct colors
cmap = plt.get_cmap("tab20", len(industries))

# Make the figure wider to give the plot more horizontal space
plt.figure(figsize=(11, 6))

# Plot each industry so it appears in the legend
for ind in industries:
    df = scatter_data[scatter_data["industry_title_clean"] == ind]
    plt.scatter(
        df["empl_growth_pct"],
        df["wage_growth_pct"],
        label=ind.replace("NAICS ", ""),
        color=cmap(color_map[ind]),
        s=50  # slightly larger points for visibility
    )

# Reference lines at zero
plt.axhline(0, linestyle="--", linewidth=1)
plt.axvline(0, linestyle="--", linewidth=1)

# Focus x-axis on clustered industries
plt.xlim(-20, 20)

# Axis labels and title
plt.xlabel("Employment Growth (2020–2024, %)")
plt.ylabel("Wage Growth (2020–2024, %)")
plt.title("Employment vs Wage Growth by Industry")

# Smaller legend text and tighter spacing
plt.legend(
    bbox_to_anchor=(1.02, 1),
    loc="upper left",
    fontsize=7,          # smaller legend font
    labelspacing=0.6,    # tighter vertical spacing
    handletextpad=0.4
)

# Preserve space for the chart while accommodating the legend
plt.tight_layout(rect=[0, 0, 0.75, 1])

plt.show()

# %% [markdown]
# ### Industry-specific shock effects
#
# Accommodation and food services exhibits unusually large wage growth
# between 2020 and 2024. This likely reflects a depressed wage base in 2020,
# followed by post-pandemic labor shortages and rapid nominal wage adjustment.
# As a result, wage growth in this sector should be interpreted as a recovery
# from a severe shock rather than steady long-run growth.

# %%
# Compute the median wage growth across all industries
median_wage_growth = growth_combined["wage_growth_pct"].median()

median_wage_growth
# Out:
# np.float64(17.77)

# %%
# Extract wage growth for NAICS 72 (Accommodation and food services)
naics_72_wage = growth_combined.loc[
    growth_combined["industry_code"] == "72",
    "wage_growth_pct"
].iloc[0]

naics_72_wage
# Out:
# np.float64(40.96)

# %%
# Compute how much higher NAICS 72 wage growth is relative to the median
wage_gap = naics_72_wage - median_wage_growth

wage_gap
# Out:
# np.float64(23.19)

# %% [markdown]
# ### Wage growth relative to the median
#
# Accommodation and food services (NAICS 72) experienced wage growth of
# approximately **42%** between 2020 and 2024. In comparison, the median
# industry wage growth over the same period was **17.77%**. The difference
# between these two growth rates is approximately **23.19 percentage points (pp)**,
# meaning NAICS 72 wage growth was **23.19 pp higher** than the median industry.
#
# This outsized increase likely reflects a combination of a depressed wage
# base during the COVID-19 shock, acute post-pandemic labor shortages, and
# rapid nominal wage adjustment during the recovery period. As a result,
# wage growth in this sector should be interpreted primarily as a recovery
# from an extreme shock rather than steady long-run wage expansion.

# %%
# Create a working copy of the combined growth table
cost_pressure = growth_combined.copy()

# Labor cost pressure = wage growth minus employment growth (percentage points)
# Positive values indicate wages rising faster than employment
cost_pressure["labor_cost_pressure_pp"] = (
    cost_pressure["wage_growth_pct"] -
    cost_pressure["empl_growth_pct"]
).round(2)

# Sort industries from highest to lowest cost pressure
cost_pressure = cost_pressure.sort_values(
    "labor_cost_pressure_pp",
    ascending=False
)

# Display the key results
cost_pressure[
    [
        "industry_title_clean",
        "empl_growth_pct",
        "wage_growth_pct",
        "labor_cost_pressure_pp"
    ]
]
# Out:
#                                  industry_title_clean  empl_growth_pct  \
# 11           NAICS 72 Accommodation and food services            -4.65
# 15                                 NAICS 22 Utilities           -14.59
# 12  NAICS 56 Administrative and support and waste ...            -5.29
# 14        NAICS 53 Real estate and rental and leasing           -10.34
# 13                           NAICS 44-45 Retail trade            -8.59
# 10                          NAICS 31-33 Manufacturing            -3.03
# 4   NAICS 11 Agriculture, forestry, fishing and hu...             8.49
# 9                                NAICS 51 Information             0.51
# 5          NAICS 62 Health care and social assistance             7.51
# 3                      NAICS 52 Finance and insurance             8.93
# 7                       NAICS 61 Educational services             1.87
# 8          NAICS 48-49 Transportation and warehousing             0.73
# 1   NAICS 81 Other services (except public adminis...            11.35
# 2        NAICS 71 Arts, entertainment, and recreation            10.20
# 6   NAICS 54 Professional, scientific, and technic...             5.67
# 0                               NAICS 23 Construction           575.00
#
#     wage_growth_pct  labor_cost_pressure_pp
# 11            40.96                   45.61
# 15            15.59                   30.18
# 12            24.33                   29.62
# 14            18.29                   28.63
# 13            15.98                   24.57
# 10            16.99                   20.02
# 4             25.77                   17.28
# 9             17.63                   17.12
# 5             22.65                   15.14
# 3             20.60                   11.67
# 7             13.17                   11.30
# 8             10.19                    9.46
# 1             19.64                    8.29
# 2             17.91                    7.71
# 6             10.09                    4.42
# 0             11.80                 -563.20

# %% [markdown]
# ### Labor cost pressure
#
# Labor cost pressure is defined as the difference between wage growth and
# employment growth, measured in percentage points. Positive values indicate
# industries where labor costs have increased faster than workforce expansion.

# %% [markdown]
# ### Industries with highest labor cost pressure
#
# Accommodation and food services, utilities, and administrative and waste
# services exhibit the highest labor cost pressure, defined as wage growth
# substantially exceeding employment growth. While accommodation and food
# services reflects post-pandemic recovery dynamics, utilities and
# administrative services display patterns more indicative of structural
# labor constraints and rising per-worker costs.
#
# These conditions suggest environments in which private equity strategies
# focused on consolidation, automation, or operational restructuring may be
# particularly relevant.

# %% [markdown]
# ### Payroll growth as context
#
# To distinguish per-worker wage changes from overall labor spending,
# we approximate total annual payroll as average weekly wage multiplied
# by average employment and 52 weeks. Payroll growth provides a measure
# of how total labor compensation has changed within each industry,
# incorporating both wage and employment dynamics.

# %%
# Compute payroll growth between 2020 and 2024
payroll_growth = (
    (wide_payroll[2024] / wide_payroll[2020] - 1)
    .rename("payroll_growth_2020_2024")
    .reset_index()
)

# Convert to percentage terms
payroll_growth["payroll_growth_pct"] = (
    100 * payroll_growth["payroll_growth_2020_2024"]
).round(2)

# Merge payroll growth into the existing growth table
growth_plus = growth_combined.merge(
    payroll_growth[
        ["industry_code", "industry_title_clean", "payroll_growth_pct"]
    ],
    on=["industry_code", "industry_title_clean"],
    how="left"
)

# %%
growth_plus["labor_cost_pressure_pp"] = (
    growth_plus["wage_growth_pct"] - growth_plus["empl_growth_pct"]
).round(2)

# %%
growth_plus[
    [
        "industry_title_clean",
        "empl_growth_pct",
        "wage_growth_pct",
        "payroll_growth_pct",
        "labor_cost_pressure_pp",
    ]
].sort_values("labor_cost_pressure_pp", ascending=False)
# Out:
#                                  industry_title_clean  empl_growth_pct  \
# 11           NAICS 72 Accommodation and food services            -4.65
# 15                                 NAICS 22 Utilities           -14.59
# 12  NAICS 56 Administrative and support and waste ...            -5.29
# 14        NAICS 53 Real estate and rental and leasing           -10.34
# 13                           NAICS 44-45 Retail trade            -8.59
# 10                          NAICS 31-33 Manufacturing            -3.03
# 4   NAICS 11 Agriculture, forestry, fishing and hu...             8.49
# 9                                NAICS 51 Information             0.51
# 5          NAICS 62 Health care and social assistance             7.51
# 3                      NAICS 52 Finance and insurance             8.93
# 7                       NAICS 61 Educational services             1.87
# 8          NAICS 48-49 Transportation and warehousing             0.73
# 1   NAICS 81 Other services (except public adminis...            11.35
# 2        NAICS 71 Arts, entertainment, and recreation            10.20
# 6   NAICS 54 Professional, scientific, and technic...             5.67
# 0                               NAICS 23 Construction           575.00
#
#     wage_growth_pct  payroll_growth_pct  labor_cost_pressure_pp
# 11            40.96               34.41                   45.61
# 15            15.59               -1.27                   30.18
# 12            24.33               17.75                   29.62
# 14            18.29                6.05                   28.63
# 13            15.98                6.02                   24.57
# 10            16.99               13.45                   20.02
# 4             25.77               36.44                   17.28
# 9             17.63               18.23                   17.12
# 5             22.65               31.87                   15.14
# 3             20.60               31.36                   11.67
# 7             13.17               15.29                   11.30
# 8             10.19               11.00                    9.46
# 1             19.64               33.23                    8.29
# 2             17.91               29.94                    7.71
# 6             10.09               16.34                    4.42
# 0             11.80              654.67                 -563.20

# %%
growth_plus.loc[
    growth_plus["industry_code"].isin(["72", "22", "56"]),
    [
        "industry_title_clean",
        "empl_growth_pct",
        "wage_growth_pct",
        "payroll_growth_pct",
        "labor_cost_pressure_pp",
    ]
]
# Out:
#                                  industry_title_clean  empl_growth_pct  \
# 11           NAICS 72 Accommodation and food services            -4.65
# 12  NAICS 56 Administrative and support and waste ...            -5.29
# 15                                 NAICS 22 Utilities           -14.59
#
#     wage_growth_pct  payroll_growth_pct  labor_cost_pressure_pp
# 11            40.96               34.41                   45.61
# 12            24.33               17.75                   29.62
# 15            15.59               -1.27                   30.18
